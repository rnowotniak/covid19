# %% [markdown]
# # covid19 spread analysis
# Coronavirus spread analysis in Python, Jupyter and pandas
#
# Contact: Robert Nowotniak <rnowotniak@gmail.com>
#
# **Last updated:  Apr 5th, 2020**
#
#
# ----
#
#
#
# * https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
#
#
#
# * docker pull jupyter/scipy-notebook
# * docker run -p 8888:8888 -v "$PWD:/home/jovyan/work"   --rm jupyter/scipy-notebook
#
# * Data source: https://github.com/CSSEGISandData/COVID-19
# * Docker image: jupyter/minimal-notebook

# %%
import pandas as pd, numpy as np

# %% [markdown]
# Data from John Hopkin University:

# %%
DATA_URL='https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'

# %%
data=pd.read_csv(DATA_URL)

# %%
data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/26/20  3/27/20  3/28/20  3/29/20  \
# 0        0        0        0  ...       94      110      110      120
# 1        0        0        0  ...      174      186      197      212
# 2        0        0        0  ...      367      409      454      511
# 3        0        0        0  ...      224      267      308      334
# 4        0        0        0  ...        4        4        5        7
#
#    3/30/20  3/31/20  4/1/20  4/2/20  4/3/20  4/4/20
# 0      170      174     237     273     281     299
# 1      223      243     259     277     304     333
# 2      584      716     847     986    1171    1251
# 3      370      376     390     428     439     466
# 4        7        7       8       8       8      10
#
# [5 rows x 78 columns]

# %% [markdown]
# Discard Province/State information

# %%
data.groupby(by='Country/Region').sum().transpose()['China'][2:].plot()

# %%
data.groupby(by='Country/Region').sum().transpose()['US'][2:].plot()

# %%
data.groupby(by='Country/Region').sum().transpose()['China'][2:].plot()

# %%
data.set_index(['Country/Region','Province/State']).transpose()['Poland',np.nan][2:].plot()

# %%
data.set_index(['Country/Region','Province/State']).transpose()['China']
# Out:
# Province/State     Anhui   Beijing  Chongqing    Fujian     Gansu  Guangdong  \
# Lat              31.8257   40.1824    30.0572   26.0789   37.8099    23.3417
# Long            117.2264  116.4142   107.8740  117.9874  101.0583   113.4244
# 1/22/20           1.0000   14.0000     6.0000    1.0000    0.0000    26.0000
# 1/23/20           9.0000   22.0000     9.0000    5.0000    2.0000    32.0000
# 1/24/20          15.0000   36.0000    27.0000   10.0000    2.0000    53.0000
# ...                  ...       ...        ...       ...       ...        ...
# 3/31/20         990.0000  580.0000   579.0000  343.0000  138.0000  1494.0000
# 4/1/20          990.0000  580.0000   579.0000  345.0000  138.0000  1501.0000
# 4/2/20          990.0000  582.0000   579.0000  345.0000  138.0000  1507.0000
# 4/3/20          990.0000  584.0000   579.0000  349.0000  138.0000  1514.0000
# 4/4/20          990.0000  585.0000   579.0000  350.0000  138.0000  1516.0000
#
# Province/State   Guangxi   Guizhou    Hainan     Hebei  ...   Shaanxi  \
# Lat              23.8298   26.8154   19.1959   39.5490  ...   35.1917
# Long            108.7881  106.8748  109.7453  116.1306  ...  108.8701
# 1/22/20           2.0000    1.0000    4.0000    1.0000  ...    0.0000
# 1/23/20           5.0000    3.0000    5.0000    1.0000  ...    3.0000
# 1/24/20          23.0000    3.0000    8.0000    2.0000  ...    5.0000
# ...                  ...       ...       ...       ...  ...       ...
# 3/31/20         254.0000  146.0000  168.0000  321.0000  ...  253.0000
# 4/1/20          254.0000  146.0000  168.0000  323.0000  ...  255.0000
# 4/2/20          254.0000  146.0000  168.0000  325.0000  ...  255.0000
# 4/3/20          254.0000  146.0000  168.0000  326.0000  ...  255.0000
# 4/4/20          254.0000  146.0000  168.0000  326.0000  ...  256.0000
#
# Province/State  Shandong  Shanghai    Shanxi   Sichuan   Tianjin    Tibet  \
# Lat              36.3427   31.2020   37.5777   30.6171   39.3054  31.6927
# Long            118.1498  121.4491  112.2922  102.7103  117.3230  88.0924
# 1/22/20           2.0000    9.0000    1.0000    5.0000    4.0000   0.0000
# 1/23/20           6.0000   16.0000    1.0000    8.0000    4.0000   0.0000
# 1/24/20          15.0000   20.0000    1.0000   15.0000    8.0000   0.0000
# ...                  ...       ...       ...       ...       ...      ...
# 3/31/20         774.0000  509.0000  136.0000  550.0000  174.0000   1.0000
# 4/1/20          774.0000  516.0000  137.0000  552.0000  176.0000   1.0000
# 4/2/20          775.0000  522.0000  137.0000  554.0000  176.0000   1.0000
# 4/3/20          778.0000  526.0000  137.0000  555.0000  180.0000   1.0000
# 4/4/20          778.0000  529.0000  137.0000  557.0000  180.0000   1.0000
#
# Province/State  Xinjiang   Yunnan   Zhejiang
# Lat              41.1129   24.974    29.1832
# Long             85.2401  101.487   120.0934
# 1/22/20           0.0000    1.000    10.0000
# 1/23/20           2.0000    2.000    27.0000
# 1/24/20           2.0000    5.000    43.0000
# ...                  ...      ...        ...
# 3/31/20          76.0000  182.000  1257.0000
# 4/1/20           76.0000  182.000  1257.0000
# 4/2/20           76.0000  183.000  1258.0000
# 4/3/20           76.0000  184.000  1260.0000
# 4/4/20           76.0000  184.000  1262.0000
#
# [76 rows x 33 columns]

# %%
data.set_index(['Country/Region','Province/State']).transpose()['China','Hebei'][2:].plot()

# %%
data[data['Country/Region'] == 'Poland']
# Out:
#     Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# 183            NaN         Poland  51.9194  19.1451        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/26/20  3/27/20  3/28/20  \
# 183        0        0        0        0  ...     1221     1389     1638
#
#      3/29/20  3/30/20  3/31/20  4/1/20  4/2/20  4/3/20  4/4/20
# 183     1862     2055     2311    2554    2946    3383    3627
#
# [1 rows x 78 columns]
